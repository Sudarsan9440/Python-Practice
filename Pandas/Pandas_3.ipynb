# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudarsan9440/Python-Practice/blob/main/Pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/survey_results_schema.csv",index_col='qid')

# %%
df
# Out:
#               qname                                           question  \
# qid
# QID16            S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12      MetaInfo                                  Browser Meta Info
# QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# QID312         Q120
# QID1             S1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# QID289  Knowledge_7  Waiting on answers to questions often causes i...
# QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# QID290  Frequency_1  Needing help from people outside of your immed...
# QID290  Frequency_2  Interacting with people outside of your immedi...
# QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID310      False    DB       TB
# ...

# %%
people ={
    "first": ["John","Jane","Joe"],
    "last": ["Doe","Doe","Doe"],
    "email": ["john.doe@example.com","jane.doe@example.com","joe.doe@example.com"]
}

# %%
df=pd.DataFrame(people)

# %%
df.set_index("email",inplace=True)

# %%
df.loc["QID290",'question']
# Out:
# qid
# QID290    How frequently do you experience each of the f...
# QID290    Needing help from people outside of your immed...
# QID290    Interacting with people outside of your immedi...
# QID290    Encountering knowledge silos (where one indivi...
# Name: question, dtype: object

# %%
df.index
# Out:
# Index(['john.doe@example.com', 'jane.doe@example.com', 'joe.doe@example.com'], dtype='object', name='email')

# %%
df.loc["john.doe@example.com"]
# Out:
# first    John
# last      Doe
# Name: john.doe@example.com, dtype: object

# %%
df.loc["john.doe@example.com",'last']
# Out:
# 'Doe'

# %%
df.iloc[0]
# Out:
# first    John
# last      Doe
# Name: john.doe@example.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                   email first last
# 0  john.doe@example.com  John  Doe
# 1  jane.doe@example.com  Jane  Doe
# 2   joe.doe@example.com   Joe  Doe

# %%
df.sort_index(ascending=False)
# Out:
#               qname                                           question  \
# qid
# QID91            S4  <span style="font-size:22px; font-family: aria...
# QID71         OpSys  What is the primary <b>operating system</b> in...
# QID61            S3  <span style="font-size:22px; font-family: aria...
# QID6        Country  Where do you live? <span style="font-weight: b...
# QID51     CompTotal  What is your current total <b>annual</b> compe...
# ...             ...                                                ...
# QID106       SOComm  Do you consider yourself a member of the Stack...
# QID102   SOPartFreq  How frequently would you say you participate i...
# QID101    SOAccount              Do you have a Stack Overflow account?
# QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# QID1             S1  <span style="font-size:22px; font-family: aria...
#
#        force_resp    type selector
# qid
# QID91       False      DB       TB
# ...
